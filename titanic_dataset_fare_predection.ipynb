# %% [markdown]
# <a href="https://colab.research.google.com/github/Subratamanna07/titanic_dataset_fare-predection/blob/main/titanic_dataset_fare_predection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/titanic/train.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# look at numeric and categorical values separately 
df_num = df[['Age','SibSp','Parch','Fare']]
df_cat = df[['Survived','Pclass','Sex','Ticket','Cabin','Embarked']]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# list columns
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
#quick look at our data types & null counts 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# to better understand the numeric data, we want to use the .describe() method. This gives us an understanding of the central tendencies of the data 
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#quick way to separate numeric columns
df.describe().columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %% [markdown]
# #### Univariate Analysis

# %%
for col in ['Survived','Pclass', 'Age', 'Fare','SibSp','Parch']:
  min_val, max_val = df[col].min(), df[col].max()
  # print('Minimum value of ' + col + ' is ' + str(min_val) + ' and Maximum value of ' +   col + ' is ' + str(max_val))
  # print("Minimum value of ", col, " is ", min_val," and Maximum value of ", col," is ",max_val)
  print(f'Minimum value of {col} is {min_val} and Maximum value of {col} is {max_val}')
# Out:
# Minimum value of Survived is 0 and Maximum value of Survived is 1
# Minimum value of Pclass is 1 and Maximum value of Pclass is 3
# Minimum value of Age is 0.42 and Maximum value of Age is 80.0
# Minimum value of Fare is 0.0 and Maximum value of Fare is 512.3292
# Minimum value of SibSp is 0 and Maximum value of SibSp is 8
# Minimum value of Parch is 0 and Maximum value of Parch is 6

# %%
for col in ['Sex','Embarked']:
  vals = df[col].unique()
  print(f'Unique values/classes in {col} are {vals}' )
# Out:
# Unique values/classes in Sex are ['male' 'female']
# Unique values/classes in Embarked are ['S' 'C' 'Q' nan]

# %%
#quick look at our data
sns.pairplot(df)

# %% [markdown]
# ### Handling missing values

# %%
# drop the cabin column from the dataframe
df = df.drop(columns='Cabin', axis=1)

# %%
# drop the name column beacuse mixed col from the dataframe
df = df.drop(columns='Name', axis=1)

# %%
# drop the pessanger id  (unique id ) columns from the dataframe
df = df.drop(columns='PassengerId', axis=1)

# %%
# drop the Ticket  (mixed col ) columns from the dataframe
df = df.drop(columns='Ticket', axis=1)

# %%
# replacing the missing values in "Age" column with mean value
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
## removing embarked null values and all col
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
#showing rows and col
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  889 non-null    int64
#  1   Pclass    889 non-null    int64
#  2   Sex       889 non-null    object
#  3   Age       889 non-null    float64
#  4   SibSp     889 non-null    int64
#  5   Parch     889 non-null    int64
#  6   Fare      889 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 62.5+ KB

# %%
# Multiple pairwise bivariate distributions in a dataset
sns.set_style("ticks")
sns.pairplot(df, hue='Sex', diag_kind="hist", palette="husl")
plt.show()

# %%
def get_distro(df,col):
  plt.figure(figsize=(18,6))

  plt.subplot(1,4,1)
  plt.hist(df[col],bins=30)
  plt.title('Hist')
  plt.subplot(1,4,2)
  stats.probplot(df[col],dist='norm',plot=plt)
  plt.ylabel('quantiles')
  plt.subplot(1,4,3)
  sns.boxplot(y=df[col])
  plt.title('Boxplot')
  plt.show()
  plt.subplot(1,4,4)
  sns.distplot(df[col], hist=False)
  plt.show()

# %%
get_distro(df,'Age')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
get_distro(df,'Fare')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
get_distro(df,'Parch')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
get_distro(df,'SibSp')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Bivaraite analysis

# %%
##corelation matrix
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)

# %%
# Multiple pairwise bivariate distributions in a dataset
sns.set_style("ticks")
sns.pairplot(df, hue='Sex', diag_kind="hist", palette="husl")
plt.show()

# %%
# Draw a vertical boxplot grouped 
# by a categorical variable:
sns.set_style("whitegrid")
  
sns.boxplot(x = 'Sex', y = 'Fare', data = df)

# %%
sns.violinplot(x='Parch',y ='Fare',data=df,palette='rainbow',hue='Sex',splt='true')

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x="Age", y="Fare", hue="Sex", data=df)
plt.show()

# %%
sns.violinplot(x="Fare", y="Age", hue='Sex', data=df)
plt.show()

# %%
# Normal distribution conditions
# 1. mean == median
# 2. data coverage : -sigma to +sigma - 67%  , -2sigma to +2sigma - 95% , -2sigma to +3sigma - 99.5%

# %%
# plot numerical columns

plt.figure(figsize=(8,8))
sns.distplot(df['Age'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,8))
sns.distplot(df.Pclass)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,8))
sns.distplot(df.Fare)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.Survived)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.Parch)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.SibSp)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
##showing the categorical col by using Bar plot

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    312
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts().plot(kind='bar')

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.Embarked.value_counts().plot(kind='bar')

# %%
## Find relation between independent categorical variables and target variables
plt.figure(figsize = (10,6))
sns.boxplot(y = 'Fare', x = 'Sex', data=df)

# %%
plt.figure(figsize = (10,6))
sns.boxplot(y = 'Fare', x = 'Embarked', data=df)

# %%
# create converting negative values into a positive values
# relation between target variable into numerical variable
f, ax= plt.subplots(figsize = (15,8))
plt.title("Correlation of Numerical Variable including Target variable")

sns.heatmap(df[['Age', 'Pclass', 'Survived', 'SibSp','Parch','Fare']].corr(), square=True)

# %%
plt.subplots(figsize=(10, 10))
sns.regplot(x="Age", y="Fare", data=df)
plt.show()

# %%
sns.jointplot(x='Age',y='Fare',data=df)
plt.show()

# %% [markdown]
# ### Outlier Detection

# %%
def find_normal_outlier(df,col):
  upper_limit = df[col].mean() + 3*df[col].std()
  lower_limit = df[col].mean() - 3*df[col].std()
  return upper_limit, lower_limit

# %%
find_normal_outlier(df,'Age')
# Out:
# (68.55854529843121, -9.25165255708271)

# %%
def find_skewed_outliers(df, col, distance):

  IQR = df[col].quantile(0.75)- df[col].quantile(0.25)
  upper_limit= df[col].quantile(0.75) + (IQR*distance)
  lower_limit= df[col].quantile(0.25) - (IQR*distance)
  return lower_limit, upper_limit

# %%
find_skewed_outliers(df,'Fare', 1.5)
# Out:
# (-26.7605, 65.6563)

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
def detect_outliers(a):
    outliers = []
    threshold = 3
    mean = np.mean(a)
    std = np.std(a)
    
    for i in a:
        z_score = (i-mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers
    pass

# %%
age_out = detect_outliers(df['Age'])
age_out
# Out:
# [71.0, 70.5, 71.0, 80.0, 70.0, 70.0, 74.0]

# %%
Fare_out= detect_outliers(df['Fare'])

# %%
Fare_out
# Out:
# [263.0,
#  263.0,
#  247.5208,
#  512.3292,
#  247.5208,
#  262.375,
#  263.0,
#  211.5,
#  227.525,
#  263.0,
#  221.7792,
#  227.525,
#  512.3292,
#  211.3375,
#  227.525,
#  227.525,
#  211.3375,
#  512.3292,
#  262.375,
#  211.3375]

# %%
# Convert outliers to deletable format
# We are using this as outliers may have same value which will cause error while deleting

def process_outliers(a):
    convert_list = list(set(a))
    return convert_list

# %%
list_age=process_outliers(age_out)
list_age
# Out:
# [70.0, 70.5, 71.0, 74.0, 80.0]

# %%
# Fare outlier  detect
List_fare=process_outliers(Fare_out)
List_fare
# Out:
# [512.3292, 227.525, 262.375, 263.0, 211.5, 211.3375, 247.5208, 221.7792]

# %%
def delete_outlier(a,ddf):   # a-> list of outliers, df-> dataframe from which we have to delete
    for x in a:
        df.drop(df[ddf == x].index,inplace = True)

# %%
delete_outlier(list_age,df['Age'])
# Out:
# <ipython-input-65-3c6eca592217>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.drop(df[ddf == x].index,inplace = True)

# %%
delete_outlier(List_fare,df['Fare'])
# Out:
# <ipython-input-65-3c6eca592217>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.drop(df[ddf == x].index,inplace = True)

# %%
## showing outlier for age
sns.boxplot(df['Age'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
find_skewed_outliers(df,'Fare', 1.5)
# Out:
# (-24.810499999999998, 62.4063)

# %%
find_normal_outlier(df,'Fare')
# Out:
# (114.33926268079327, -61.58614203114129)

# %%
delete_outlier(List_fare,df['Fare'])

# %%
print(df['Fare'].skew())
# Out:
# 2.2794241344407626

# %%
# Removing outiers by logatrithamic transformation of 'fare' column
df["Fare"] = df["Fare"].map(lambda i: np.log(i) if i > 0 else 0)

# %%
## showing outlier for Fare
sns.boxplot(df['Fare'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(df['Fare'].skew())
# Out:
# 0.1961229167513516

# %%
df['Fare'].max()
# Out:
# 5.1051372686027685

# %%
df['Fare'].min()
# Out:
# 0.0

# %% [markdown]
# ## Feature Engineering
# ####Column transformation : OHE and Normalization

# %%
## one hot encoding for categorical variable

# %%
df =df.join(pd.get_dummies(df.Embarked)).drop(["Embarked"],axis=1)
df =df.join(pd.get_dummies(df.Sex)).drop(["Sex"],axis=1)

# %%
## column transformation by normalization for normal distribution

# %%
# Column trnsformation by logarithomic transformation
df['Age'] = np.log(df['Age']+1)

# %%
## corelation after feature engineering
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ####Modeling

# %% [markdown]
# ## Modeling

# %%
# Dropping target varaible
from sklearn.model_selection import train_test_split
x = df.drop(["Fare"],axis=1)
y = df["Fare"]

# %%
x_train,x_val,y_train,y_val=train_test_split(x,y,test_size=0.2,random_state=2 )

# %%
x_train.shape, x_val.shape
# Out:
# ((689, 10), (173, 10))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
# Linear regression
from sklearn.linear_model import LinearRegression
x_train,y_train = df.drop(["Fare"],axis=1),df["Fare"]
reg= LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = reg.predict(x_val)

# %%
pred
# Out:
# array([2.09765625, 2.515625  , 3.6484375 , 2.7109375 , 2.0078125 ,
#        2.0078125 , 2.703125  , 2.078125  , 4.140625  , 2.28125   ,
#        2.703125  , 3.63671875, 2.015625  , 3.63671875, 2.94140625,
#        3.8125    , 2.9296875 , 2.        , 2.8828125 , 2.0078125 ,
#        3.5390625 , 2.7109375 , 3.546875  , 3.453125  , 2.0078125 ,
#        2.0078125 , 2.125     , 2.        , 2.578125  , 3.6875    ,
#        3.421875  , 3.296875  , 2.9375    , 4.15625   , 2.984375  ,
#        3.421875  , 2.63671875, 4.14453125, 3.25      , 2.2421875 ,
#        3.4140625 , 4.1796875 , 4.2578125 , 2.78125   , 2.50390625,
#        2.71875   , 2.7109375 , 3.5546875 , 2.80078125, 3.78125   ,
#        2.9453125 , 2.        , 2.        , 2.0078125 , 2.25      ,
#        2.578125  , 2.0078125 , 2.        , 2.1640625 , 2.75      ,
#        2.7109375 , 2.0078125 , 2.        , 2.7109375 , 2.        ,
#        2.0078125 , 3.87890625, 2.546875  , 2.0078125 , 2.59765625,
#        2.0703125 , 2.        , 2.984375  , 2.59375   , 2.94140625,
#        2.93359375, 2.9375    , 2.        , 3.421875  , 2.7109375 ,
#        3.12109375, 3.40234375, 2.37109375, 2.15625   , 3.6640625 ,
#        3.44921875, 2.125     , 1.9921875 , 3.03125   , 2.703125  ,
#        2.0078125 , 3.65625   , 2.0078125 , 3.87109375, 2.        ,
#        2.1640625 , 3.234375  , 2.703125  , 3.6875    , 3.91015625,
#        2.0703125 , 2.28125   , 2.2421875 , 2.0078125 , 2.8359375 ,
#        3.1640625 , 4.1484375 , 4.12109375, 2.0625    , 2.703125  ,
#        2.7109375 , 2.3671875 , 2.09375   , 2.25      , 3.203125  ,
#        2.2890625 , 2.2734375 , 3.421875  , 2.7109375 , 2.703125  ,
#        2.1328125 , 4.0546875 , 4.6796875 , 2.2421875 , 2.1328125 ,
#        3.90625   , 4.15625   , 3.8515625 , 2.7109375 , 3.6484375 ,
#        2.375     , 2.7109375 , 2.        , 2.140625  , 2.68359375,
#        3.97265625, 2.28125   , 3.66015625, 4.3984375 , 3.421875  ,
#        3.203125  , 2.9765625 , 3.78515625, 3.6484375 , 2.6015625 ,
#        4.15234375, 2.7109375 , 2.9296875 , 2.28125   , 2.71875   ,
#        3.6953125 , 2.2890625 , 2.703125  , 2.        , 2.7109375 ,
#        4.14453125, 2.71875   , 2.2421875 , 2.7109375 , 3.421875  ,
#        2.0703125 , 3.62890625, 2.2265625 , 3.7890625 , 4.1484375 ,
#        2.0078125 , 2.0703125 , 3.875     , 4.1640625 , 4.7734375 ,
#        2.0078125 , 3.21875   , 2.        ])

# %%
# R square 
reg.score(x_val,y_val)
# Out:
# 0.7770318489443012

# %%
#cofficient and intercept regression of regression
reg.coef_  ,reg.intercept_
# Out:
# (array([ 1.26904993e-01, -7.03622495e-01,  1.62706760e-02,  2.72498462e-01,
#          2.45817388e-01, -2.23551515e+13, -2.23551515e+13, -2.23551515e+13,
#          4.62966824e+12,  4.62966824e+12]), 17725483224893.93)

# %%
from sklearn.metrics import mean_squared_error

mse= mean_squared_error(pred, y_val)
mse
# Out:
# 0.1788240104889461

# %%
from sklearn.metrics import mean_absolute_error
mae_train = mean_absolute_error(y_val,pred)
print(mae_train)
# Out:
# 0.28432758838473005

# %% [markdown]
# #### regression plot of the features correlated with the

# %%
from matplotlib.gridspec import tight_layout
from seaborn.regression import regplot
rows = 2
cols = 5
fig, ax= plt.subplots(nrows=rows, ncols=cols, figsize =(16,4))

col = df.columns
index = 0

for i in range(rows):
  for j in range(cols):
    sns.regplot(x = df[col[index]], y= df['Fare'], ax= ax[i][j])
    index = index+1

fig.tight_layout()
